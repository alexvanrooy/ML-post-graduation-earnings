# %%
#IMPORTS
import pandas as pd
from sklearn.model_selection import train_test_split

# %% [markdown]
# This notebook is just to compare the ouput of splitting the data using the class in DataPreprocessing vs doing it manually. If they match then it is a success

# %%
X = pd.read_csv('..\data\interim\X.csv', index_col = 0)
y = pd.read_csv('..\data\interim\y.csv', index_col = 0)

# %%
display(X.shape[0])
# Out:
# 5003

# %%
X_train = pd.read_csv('..\data\processed\X_train.csv', index_col = 0)
X_test = pd.read_csv('..\data\processed\X_test.csv', index_col = 0)

print(f"TRAIN SET SIZE: {X_train.shape[0]}")
print(f"TEST SET SIZE: {X_test.shape[0]}")
# Out:
# TRAIN SET SIZE: 3502
# TEST SET SIZE: 1501

# %%
display(X_train)
# Out:
#       SCH_DEG  MAIN  NUMBRANCH  PREDDEG  HIGHDEG  CONTROL  CCBASIC  CCUGPROF  \
# 4686      1.0     1          1        1        1        3     -2.0      -2.0
# 3801      1.0     1          1        1        1        3     -2.0      -2.0
# 4440      1.0     0          6        1        1        3     -2.0      -2.0
# 1146      1.0     1          1        1        1        2     -2.0      -2.0
# 4610      1.0     0          3        1        1        3     -2.0      -2.0
# ...       ...   ...        ...      ...      ...      ...      ...       ...
# 4426      1.0     1          1        1        1        3     -2.0      -2.0
# 466       3.0     1          1        3        3        2     24.0       5.0
# 3092      1.0     1          1        1        2        1      3.0       1.0
# 3772      1.0     0          4        1        1        3     -2.0      -2.0
# 860       3.0     1          1        3        4        2     18.0      13.0
#
# ...

# %%
X_train_df = pd.read_csv('..\data\processed\X_train.csv', index_col=0)
display(X_train_df)
# Out:
#       SCH_DEG  MAIN  NUMBRANCH  PREDDEG  HIGHDEG  CONTROL  CCBASIC  CCUGPROF  \
# 0         1.0     1          1        1        1        3     -2.0      -2.0
# 1         1.0     1          1        1        1        3     -2.0      -2.0
# 2         1.0     0          6        1        1        3     -2.0      -2.0
# 3         1.0     1          1        1        1        2     -2.0      -2.0
# 4         1.0     0          3        1        1        3     -2.0      -2.0
# ...       ...   ...        ...      ...      ...      ...      ...       ...
# 3497      1.0     1          1        1        1        3     -2.0      -2.0
# 3498      3.0     1          1        3        3        2     24.0       5.0
# 3499      1.0     1          1        1        2        1      3.0       1.0
# 3500      1.0     0          4        1        1        3     -2.0      -2.0
# 3501      3.0     1          1        3        4        2     18.0      13.0
#
# ...
